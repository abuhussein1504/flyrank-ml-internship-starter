# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# > The overall business task is ranking/scoring, while the underlying ML model is a classification model that predicts decline probability.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# > The starter dataset uses `is_declining_label` as a proxy target. It identifies whether a page is currently declining. In a future capstone, this could be replaced with a stronger future-looking target.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# > I'll use `Precision@K` because it measures the quality of the pages that the model filters to the top of the list, and it fits the way a content team works that reviews a limited number of pages per day.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/abuhussein1504/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
os.chdir(REPO_DIR)
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found — are you at the repo root?"
print("Starter data found. You're ready.")

# %%
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

df.head().T

# %%
print(df.shape)

# %% [markdown]
# > Each row represents a single content page, and contains a set of properties such as number of impressions, number of clicks, and other indicators used to evaluate the page's performance.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# Example of a rule:
#
# `IF impressions > 500`
#
# `AND page older than 180 days`
#
# `THEN review page`
#
# That's a fixed rule.
#
# ML is better because it can combine many signals at once.
#
# For example:`[impressions, click, CTR, average position, freshness, engagement, AI traffic, word count]`
#
# > Instead of manually inventing hundreds of rules, the model learns patterns from data and estimates which pages deserve review. The final output is still reviewed by humans.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
